# %%
# !pip uninstall tensorflow --yes
# Out:
# Found existing installation: tensorflow 2.7.0
# Uninstalling tensorflow-2.7.0:
#   Successfully uninstalled tensorflow-2.7.0

# %%
# !pip install tensorflow==2.2.0
# Out:
# Collecting tensorflow==2.2.0
#   Downloading tensorflow-2.2.0-cp37-cp37m-manylinux2010_x86_64.whl (516.2 MB)
#      |████████████████████████████████| 516.2 MB 4.3 kB/s
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.37.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.1.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.4.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.19.5)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.6.3)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (3.17.3)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 55.2 MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (3.3.0)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
#      |████████████████████████████████| 454 kB 47.5 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.43.0)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.13.3)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 67.8 MB/s
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.2.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.3.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.1.1)
# Installing collected packages: tensorflow-estimator, tensorboard, h5py, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
#       Successfully uninstalled tensorboard-2.7.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
# Successfully installed gast-0.3.3 h5py-2.10.0 tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0

# %%
import glob
import pandas  as pd
import numpy   as np
import nibabel as nib
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from zipfile import ZipFile
from shutil import copyfile, copyfileobj
import gzip
from IPython.display import clear_output
import cv2
import os
from pylab import rcParams
import PIL
from PIL import Image
import scipy
from google.colab import files
from sklearn.model_selection import train_test_split
from google.colab import drive
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, MeanShift
import imgaug as ia
import imgaug.augmenters as iaa
from sklearn.utils import class_weight

print("Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("GPU is", "available" if tf.config.experimental.list_physical_devices("GPU") else "NOT AVAILABLE")
# Out:
# Version:  2.2.0
# Eager mode:  True
# GPU is available

# %%
import sys
import random
import warnings

import math
import seaborn as sns; sns.set()
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.losses import binary_crossentropy
from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from tensorflow.keras.layers import Lambda, RepeatVector, Reshape
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.layers import concatenate, add
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras import backend as K
import joblib
import gc
#import segmentation_models as sm

# %%
os.environ['KAGGLE_USERNAME'] = "sanjanav98"
os.environ['KAGGLE_KEY'] = "2bb32d3324e753a524b072e9775b3e7a"

# %%
# !kaggle datasets download -d andrewmvd/covid19-ct-scans
# Out:
# Downloading covid19-ct-scans.zip to /content
#  99% 1.02G/1.03G [00:11<00:00, 129MB/s]
# 100% 1.03G/1.03G [00:11<00:00, 99.9MB/s]

# %%
with ZipFile('covid19-ct-scans.zip', 'r') as zipObj:
   # Extract all the contents of zip file in current directory
   zipObj.extractall('covid19-ct-scans')

# %%
raw_data = pd.read_csv('/content/covid19-ct-scans/metadata.csv')
raw_data = raw_data.replace('../input/covid19-ct-scans/','/content/covid19-ct-scans/',regex=True)
raw_data.head(5)
# Out:
#                                              ct_scan  ...                            lung_and_infection_mask
# 0  /content/covid19-ct-scans/ct_scans/coronacases...  ...  /content/covid19-ct-scans/lung_and_infection_m...
# 1  /content/covid19-ct-scans/ct_scans/coronacases...  ...  /content/covid19-ct-scans/lung_and_infection_m...
# 2  /content/covid19-ct-scans/ct_scans/coronacases...  ...  /content/covid19-ct-scans/lung_and_infection_m...
# 3  /content/covid19-ct-scans/ct_scans/coronacases...  ...  /content/covid19-ct-scans/lung_and_infection_m...
# 4  /content/covid19-ct-scans/ct_scans/coronacases...  ...  /content/covid19-ct-scans/lung_and_infection_m...
#
# [5 rows x 4 columns]

# %%
raw_data.shape
# Out:
# (20, 4)

# %%
def read_nii_demo(filepath, data):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    slices = array.shape[2]
    array = array[:,:,round(slices*0.2):round(slices*0.8)]
    array = np.reshape(np.rollaxis(array, 2),(array.shape[2],array.shape[0],array.shape[1], 1))

    for img_no in range(0, array.shape[0]):
        # array = Image.resize(array[...,img_no], (img_size,img_size))
        img = cv2.resize(array[img_no], dsize=(img_size, img_size), interpolation=cv2.INTER_AREA)
        xmax, xmin = img.max(), img.min()
        img = (img - xmin)/(xmax - xmin)
        data.append(img)

# %%
all_points1 = []
all_points2 = []

# %%
def read_nii(filepath, data, string):
    '''
    Reads .nii file and returns pixel array

    '''
    global all_points1
    global all_points2
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    slices = array.shape[2]
    array = array[:,:,round(slices*0.2):round(slices*0.8)]
    array = np.reshape(np.rollaxis(array, 2),(array.shape[2],array.shape[0],array.shape[1],1))
    #print(array.shape[2])
    #array = skimage.transform.resize(array, (array.shape[2], img_size, img_size))
    #array = cv2.resize(array, dsize=(img_size, img_size), interpolation=cv2.INTER_CUBIC)
    

    if string == "lungs":
      all_points1 = []
      all_points2 = []

    for img_no in range(0, array.shape[0]):
        if string == 'lungs' and np.unique(array[img_no]).size == 1:
          continue
        img = cv2.resize(array[img_no], dsize=(img_size, img_size), interpolation=cv2.INTER_AREA)
        xmax, xmin = img.max(), img.min()
        img = (img - xmin)/(xmax - xmin)

        if string == 'lungs':
          # img = np.uint8(img*255) 
          img[img>0]=1
          img, points1, points2 = cropper(img, demo = 0)
          all_points1.append((points1[0], points1[1], points1[2], points1[3]))
          all_points2.append((points2[0], points2[1], points2[2], points2[3]))
          continue 

        if string == "cts" and img_no < len(all_points1):
          img = clahe_enhancer(img, demo = 0)
          # img, points1, points2 = cropper(img, demo = 0)
          # all_points1.append((points1[0], points1[1], points1[2], points1[3]))
          # all_points2.append((points2[0], points2[1], points2[2], points2[3]))   
          a,b,c,d = all_points1[img_no]
          e,f,g,h = all_points2[img_no]
          img1 = img[b:b+d, a:a+c]
          img1 = cv2.resize(img1, dsize=(125,250), interpolation=cv2.INTER_AREA)
          img2 = img[f:f+h, e:e+g]
          img2 = cv2.resize(img2, dsize=(125,250), interpolation=cv2.INTER_AREA)
          img = np.concatenate((img1, img2), axis=1)    

        if string == "infections" and img_no < len(all_points1):
          a,b,c,d = all_points1[img_no]
          e,f,g,h = all_points2[img_no]
          img = np.uint8(img*255)
          img1 = img[b:b+d, a:a+c]
          img1 = cv2.resize(img1, dsize=(125,250), interpolation=cv2.INTER_AREA)
          img2 = img[f:f+h, e:e+g]
          img2 = cv2.resize(img2, dsize=(125,250), interpolation=cv2.INTER_AREA)
          img = np.concatenate((img1, img2), axis=1)


        # img = cv2.resize(img, dsize=(192, 192), interpolation=cv2.INTER_LINEAR)
        # img = img/255
        #  remember to normalize again
        # also resize images and masks for all
        
        data.append(img)

# %%
def cropper(test_img, demo):

  test_img = test_img*255
  test_img = np.uint8(test_img)

  # ret, thresh = cv2.threshold(test_img, 50, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 
  # ret, thresh = cv2.threshold(test_img, ret, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 

  contours,hierarchy = cv2.findContours(test_img, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
  areas = [cv2.contourArea(c) for c in contours]

  x = np.argsort(areas)

  max_index = x[x.size - 1]
  cnt1=contours[max_index]
  second_max_index = x[x.size - 2]
  cnt2 = contours[second_max_index]

  # max_index = np.argmax(areas)
  # cnt=contours[max_index]

  x,y,w,h = cv2.boundingRect(cnt1)
  p,q,r,s = cv2.boundingRect(cnt2)

  cropped1 = test_img[y:y+h, x:x+w]
  cropped1 = cv2.resize(cropped1, dsize=(125,250), interpolation=cv2.INTER_AREA)
  cropped2 = test_img[q:q+s, p:p+r]
  cropped2 = cv2.resize(cropped2, dsize=(125,250), interpolation=cv2.INTER_AREA)

  fused = np.concatenate((cropped1, cropped2), axis=1)

  # super_cropped = test_img[y+7:y+h-20, x+25:x+w-25]
  points_lung1 = []
  points_lung2 = []

  points_lung1.append(x); points_lung1.append(y); points_lung1.append(w); points_lung1.append(h)
  points_lung2.append(p); points_lung2.append(q); points_lung2.append(r); points_lung2.append(s)
  
  if demo == 1:

    fig = plt.figure()
    rcParams['figure.figsize'] = 35, 35

    plt.subplot(1, 3, 1)
    plt.imshow(test_img, cmap='bone')
    plt.title("Original CT-Scan")

    plt.subplot(1, 3, 2)
    plt.imshow(thresh, cmap='bone')
    plt.title("Binary Mask")

    plt.subplot(1, 3, 3)
    plt.imshow(fused, cmap='bone')
    plt.title("Cropped CT scan after making bounding rectangle")

    # plt.subplot(1, 4, 4)
    # plt.imshow(super_cropped, cmap='bone')
    # plt.title("Cropped further manually")

    plt.show()

  return(fused, points_lung1, points_lung2)

# %%
def clahe_enhancer(test_img, demo):

  test_img = test_img*255
  test_img = np.uint8(test_img)
  test_img_flattened = test_img.flatten()
  
  clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
  clahe_image = clahe.apply(test_img)
  clahe_image_flattened = clahe_image.flatten()

  if demo == 1:

    fig = plt.figure()
    rcParams['figure.figsize'] = 10,10
    
    plt.subplot(2, 2, 1)
    plt.imshow(test_img, cmap='bone')
    plt.title("Original CT-Scan")

    plt.subplot(2, 2, 2)
    plt.hist(test_img_flattened)
    plt.title("Histogram of Original CT-Scan")

    plt.subplot(2, 2, 3)
    plt.imshow(clahe_image, cmap='bone')
    plt.title("CLAHE Enhanced CT-Scan")

    plt.subplot(2, 2, 4)
    plt.hist(clahe_image_flattened)
    plt.title("Histogram of CLAHE Enhanced CT-Scan")

  return(clahe_image)

# %%
cts = []
lungs = []
infections = []

# %%
img_size = 512

# %%
for i in range(0, 20):
    read_nii(raw_data.loc[i,'lung_mask'], lungs, 'lungs')
    read_nii(raw_data.loc[i,'ct_scan'], cts, 'cts') 
    read_nii(raw_data.loc[i,'infection_mask'], infections, 'infections')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide

# %%
len(infections)/len(cts)
# Out:
# 1.0

# %%
new_dim = 224

# %%
for i in range(0,len(cts)):
  cts[i] = cv2.resize(cts[i], dsize=(new_dim, new_dim), interpolation=cv2.INTER_LINEAR)
  # cts[i] = cts[i]/255
  infections[i] = cv2.resize(infections[i], dsize=(new_dim, new_dim), interpolation=cv2.INTER_LINEAR)

# %%
cts = np.array(cts)
infections = np.array(infections)

# %%
cts = np.uint8(cts)
infections = np.uint8(infections)

# %%
cts = cts/255
infections = infections/255

# %%
cts = cts.reshape(len(cts), new_dim, new_dim, 1)
infections = infections.reshape(len(infections), new_dim, new_dim, 1)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(cts, infections, test_size=0.3, random_state=42)

# %%
print(x_train.shape, x_valid.shape)
# Out:
# (1478, 224, 224, 1) (634, 224, 224, 1)

# %%
inputs = Input((new_dim, new_dim, 1))
# s = Lambda(lambda x: x / 255) (inputs)

# def mish(inputs):
#     return inputs * tf.math.tanh(tf.math.softplus(inputs))
    
c1 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (inputs)
c1 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (c1)
c1 = BatchNormalization()(c1)
p1 = MaxPooling2D((2, 2)) (c1)
p1 = Dropout(0.25)(p1)

c2 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (p1)
c2 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (c2)
c2 = BatchNormalization()(c2)
p2 = MaxPooling2D((2, 2)) (c2)
p2 = Dropout(0.25)(p2)

c3 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (p2)
c3 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (c3)
c3 = BatchNormalization()(c3)
p3 = MaxPooling2D((2, 2)) (c3)
p3 = Dropout(0.25)(p3)

c4 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (p3)
c4 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (c4)
c4 = BatchNormalization()(c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
p4 = Dropout(0.25)(p4)

c5 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (p4)
c5 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (c5)

u6 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = concatenate([u6, c4])
u6 = BatchNormalization()(u6)
c6 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (u6)
c6 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (c6)


u7 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
u7 = BatchNormalization()(u7)
c7 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (u7)
c7 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (c7)


u8 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
u8 = BatchNormalization()(u8)
c8 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (u8)
c8 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (c8)


u9 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
u9 = BatchNormalization()(u9)
c9 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (u9)
c9 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer="he_normal") (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 112, 112, 32) 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 64) 18496       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 64) 36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 56, 56, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 28, 28, 128)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 14, 14, 256)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 14, 14, 512)  1180160     dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 512)  2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 28, 28, 256)  524544      conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 512)  0           conv2d_transpose[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 512)  2048        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 256)  1179904     batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 56, 56, 128)  131200      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 256)  0           conv2d_transpose_1[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 256)  1024        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 128)  295040      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 112, 112, 64) 32832       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 112, 112, 128 0           conv2d_transpose_2[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 112, 112, 128 512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 112, 112, 64) 73792       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 112, 112, 64) 36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 224, 224, 32) 8224        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 224, 224, 64) 0           conv2d_transpose_3[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 224, 224, 64) 256         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 224, 224, 32) 18464       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 224, 224, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 224, 224, 1)  33          conv2d_17[0][0]
# ==================================================================================================
# Total params: 7,765,281
# Trainable params: 7,762,401
# Non-trainable params: 2,880
# __________________________________________________________________________________________________

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# %%
from tensorflow.keras.losses import binary_crossentropy
def bce_dice_loss(y_true, y_pred):
    loss = 0.5*binary_crossentropy(y_true, y_pred) + 0.5*dice_loss(y_true, y_pred)
    return loss

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=bce_dice_loss,
              metrics=[dice_coeff])

# %%
checkpoint = ModelCheckpoint("best_model.hdf5", monitor='loss', verbose=1,
    save_best_only=True, mode='auto', period=1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
model.fit(
    x=x_train, y=y_train, batch_size=32, epochs=80, verbose=1,callbacks=[checkpoint])
# Out:
# Epoch 1/80
# 47/47 [==============================] - ETA: 0s - loss: 0.3964 - dice_coeff: 0.3971
# Epoch 00001: loss improved from inf to 0.39637, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 502ms/step - loss: 0.3964 - dice_coeff: 0.3971
# Epoch 2/80
# 47/47 [==============================] - ETA: 0s - loss: 0.2286 - dice_coeff: 0.6546
# Epoch 00002: loss improved from 0.39637 to 0.22855, saving model to best_model.hdf5
# 47/47 [==============================] - 22s 465ms/step - loss: 0.2286 - dice_coeff: 0.6546
# Epoch 3/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1852 - dice_coeff: 0.7223
# Epoch 00003: loss improved from 0.22855 to 0.18520, saving model to best_model.hdf5
# 47/47 [==============================] - 22s 470ms/step - loss: 0.1852 - dice_coeff: 0.7223
# Epoch 4/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1578 - dice_coeff: 0.7595
# Epoch 00004: loss improved from 0.18520 to 0.15776, saving model to best_model.hdf5
# 47/47 [==============================] - 23s 479ms/step - loss: 0.1578 - dice_coeff: 0.7595
# Epoch 5/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1439 - dice_coeff: 0.7842
# Epoch 00005: loss improved from 0.15776 to 0.14386, saving model to best_model.hdf5
# 47/47 [==============================] - 23s 495ms/step - loss: 0.1439 - dice_coeff: 0.7842
# Epoch 6/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1351 - dice_coeff: 0.7964
# Epoch 00006: loss improved from 0.14386 to 0.13506, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 513ms/step - loss: 0.1351 - dice_coeff: 0.7964
# Epoch 7/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1325 - dice_coeff: 0.7994
# Epoch 00007: loss improved from 0.13506 to 0.13250, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 518ms/step - loss: 0.1325 - dice_coeff: 0.7994
# Epoch 8/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1260 - dice_coeff: 0.8101
# Epoch 00008: loss improved from 0.13250 to 0.12596, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 506ms/step - loss: 0.1260 - dice_coeff: 0.8101
# Epoch 9/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1216 - dice_coeff: 0.8160
# Epoch 00009: loss improved from 0.12596 to 0.12157, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 508ms/step - loss: 0.1216 - dice_coeff: 0.8160
# Epoch 10/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1213 - dice_coeff: 0.8162
# Epoch 00010: loss improved from 0.12157 to 0.12128, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 514ms/step - loss: 0.1213 - dice_coeff: 0.8162
# Epoch 11/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1119 - dice_coeff: 0.8313
# Epoch 00011: loss improved from 0.12128 to 0.11189, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 511ms/step - loss: 0.1119 - dice_coeff: 0.8313
# Epoch 12/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1042 - dice_coeff: 0.8427
# Epoch 00012: loss improved from 0.11189 to 0.10420, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 509ms/step - loss: 0.1042 - dice_coeff: 0.8427
# Epoch 13/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1002 - dice_coeff: 0.8491
# Epoch 00013: loss improved from 0.10420 to 0.10023, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.1002 - dice_coeff: 0.8491
# Epoch 14/80
# 47/47 [==============================] - ETA: 0s - loss: 0.1047 - dice_coeff: 0.8423
# Epoch 00014: loss did not improve from 0.10023
# 47/47 [==============================] - 24s 504ms/step - loss: 0.1047 - dice_coeff: 0.8423
# Epoch 15/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0977 - dice_coeff: 0.8523
# Epoch 00015: loss improved from 0.10023 to 0.09771, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 512ms/step - loss: 0.0977 - dice_coeff: 0.8523
# Epoch 16/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0996 - dice_coeff: 0.8495
# Epoch 00016: loss did not improve from 0.09771
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0996 - dice_coeff: 0.8495
# Epoch 17/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0946 - dice_coeff: 0.8567
# Epoch 00017: loss improved from 0.09771 to 0.09457, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0946 - dice_coeff: 0.8567
# Epoch 18/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0879 - dice_coeff: 0.8651
# Epoch 00018: loss improved from 0.09457 to 0.08793, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0879 - dice_coeff: 0.8651
# Epoch 19/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0894 - dice_coeff: 0.8653
# Epoch 00019: loss did not improve from 0.08793
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0894 - dice_coeff: 0.8653
# Epoch 20/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0885 - dice_coeff: 0.8664
# Epoch 00020: loss did not improve from 0.08793
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0885 - dice_coeff: 0.8664
# Epoch 21/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0847 - dice_coeff: 0.8710
# Epoch 00021: loss improved from 0.08793 to 0.08474, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 509ms/step - loss: 0.0847 - dice_coeff: 0.8710
# Epoch 22/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0876 - dice_coeff: 0.8681
# Epoch 00022: loss did not improve from 0.08474
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0876 - dice_coeff: 0.8681
# Epoch 23/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0801 - dice_coeff: 0.8795
# Epoch 00023: loss improved from 0.08474 to 0.08009, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 508ms/step - loss: 0.0801 - dice_coeff: 0.8795
# Epoch 24/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0822 - dice_coeff: 0.8756
# Epoch 00024: loss did not improve from 0.08009
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0822 - dice_coeff: 0.8756
# Epoch 25/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0760 - dice_coeff: 0.8850
# Epoch 00025: loss improved from 0.08009 to 0.07604, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 509ms/step - loss: 0.0760 - dice_coeff: 0.8850
# Epoch 26/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0747 - dice_coeff: 0.8858
# Epoch 00026: loss improved from 0.07604 to 0.07474, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0747 - dice_coeff: 0.8858
# Epoch 27/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0739 - dice_coeff: 0.8880
# Epoch 00027: loss improved from 0.07474 to 0.07385, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0739 - dice_coeff: 0.8880
# Epoch 28/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0731 - dice_coeff: 0.8887
# Epoch 00028: loss improved from 0.07385 to 0.07314, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0731 - dice_coeff: 0.8887
# Epoch 29/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0696 - dice_coeff: 0.8945
# Epoch 00029: loss improved from 0.07314 to 0.06962, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0696 - dice_coeff: 0.8945
# Epoch 30/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0704 - dice_coeff: 0.8939
# Epoch 00030: loss did not improve from 0.06962
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0704 - dice_coeff: 0.8939
# Epoch 31/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0690 - dice_coeff: 0.8957
# Epoch 00031: loss improved from 0.06962 to 0.06899, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 511ms/step - loss: 0.0690 - dice_coeff: 0.8957
# Epoch 32/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0677 - dice_coeff: 0.8971
# Epoch 00032: loss improved from 0.06899 to 0.06774, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 511ms/step - loss: 0.0677 - dice_coeff: 0.8971
# Epoch 33/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0682 - dice_coeff: 0.8962
# Epoch 00033: loss did not improve from 0.06774
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0682 - dice_coeff: 0.8962
# Epoch 34/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0670 - dice_coeff: 0.8987
# Epoch 00034: loss improved from 0.06774 to 0.06700, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0670 - dice_coeff: 0.8987
# Epoch 35/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0652 - dice_coeff: 0.9011
# Epoch 00035: loss improved from 0.06700 to 0.06516, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0652 - dice_coeff: 0.9011
# Epoch 36/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0657 - dice_coeff: 0.9000
# Epoch 00036: loss did not improve from 0.06516
# 47/47 [==============================] - 24s 504ms/step - loss: 0.0657 - dice_coeff: 0.9000
# Epoch 37/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0618 - dice_coeff: 0.9067
# Epoch 00037: loss improved from 0.06516 to 0.06180, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 511ms/step - loss: 0.0618 - dice_coeff: 0.9067
# Epoch 38/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0591 - dice_coeff: 0.9097
# Epoch 00038: loss improved from 0.06180 to 0.05906, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 509ms/step - loss: 0.0591 - dice_coeff: 0.9097
# Epoch 39/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0591 - dice_coeff: 0.9103
# Epoch 00039: loss did not improve from 0.05906
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0591 - dice_coeff: 0.9103
# Epoch 40/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0580 - dice_coeff: 0.9114
# Epoch 00040: loss improved from 0.05906 to 0.05800, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 508ms/step - loss: 0.0580 - dice_coeff: 0.9114
# Epoch 41/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0588 - dice_coeff: 0.9107
# Epoch 00041: loss did not improve from 0.05800
# 47/47 [==============================] - 24s 500ms/step - loss: 0.0588 - dice_coeff: 0.9107
# Epoch 42/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0567 - dice_coeff: 0.9135
# Epoch 00042: loss improved from 0.05800 to 0.05670, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 509ms/step - loss: 0.0567 - dice_coeff: 0.9135
# Epoch 43/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0636 - dice_coeff: 0.9040
# Epoch 00043: loss did not improve from 0.05670
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0636 - dice_coeff: 0.9040
# Epoch 44/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0605 - dice_coeff: 0.9079
# Epoch 00044: loss did not improve from 0.05670
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0605 - dice_coeff: 0.9079
# Epoch 45/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0567 - dice_coeff: 0.9141
# Epoch 00045: loss improved from 0.05670 to 0.05667, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 509ms/step - loss: 0.0567 - dice_coeff: 0.9141
# Epoch 46/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0540 - dice_coeff: 0.9170
# Epoch 00046: loss improved from 0.05667 to 0.05404, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0540 - dice_coeff: 0.9170
# Epoch 47/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0543 - dice_coeff: 0.9174
# Epoch 00047: loss did not improve from 0.05404
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0543 - dice_coeff: 0.9174
# Epoch 48/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0534 - dice_coeff: 0.9187
# Epoch 00048: loss improved from 0.05404 to 0.05341, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0534 - dice_coeff: 0.9187
# Epoch 49/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0509 - dice_coeff: 0.9219
# Epoch 00049: loss improved from 0.05341 to 0.05094, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0509 - dice_coeff: 0.9219
# Epoch 50/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0509 - dice_coeff: 0.9230
# Epoch 00050: loss improved from 0.05094 to 0.05089, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0509 - dice_coeff: 0.9230
# Epoch 51/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0496 - dice_coeff: 0.9242
# Epoch 00051: loss improved from 0.05089 to 0.04960, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 512ms/step - loss: 0.0496 - dice_coeff: 0.9242
# Epoch 52/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0500 - dice_coeff: 0.9240
# Epoch 00052: loss did not improve from 0.04960
# 47/47 [==============================] - 24s 504ms/step - loss: 0.0500 - dice_coeff: 0.9240
# Epoch 53/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0492 - dice_coeff: 0.9243
# Epoch 00053: loss improved from 0.04960 to 0.04918, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 511ms/step - loss: 0.0492 - dice_coeff: 0.9243
# Epoch 54/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0494 - dice_coeff: 0.9248
# Epoch 00054: loss did not improve from 0.04918
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0494 - dice_coeff: 0.9248
# Epoch 55/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0495 - dice_coeff: 0.9244
# Epoch 00055: loss did not improve from 0.04918
# 47/47 [==============================] - 24s 504ms/step - loss: 0.0495 - dice_coeff: 0.9244
# Epoch 56/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0486 - dice_coeff: 0.9262
# Epoch 00056: loss improved from 0.04918 to 0.04865, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 511ms/step - loss: 0.0486 - dice_coeff: 0.9262
# Epoch 57/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0476 - dice_coeff: 0.9275
# Epoch 00057: loss improved from 0.04865 to 0.04757, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 512ms/step - loss: 0.0476 - dice_coeff: 0.9275
# Epoch 58/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0457 - dice_coeff: 0.9303
# Epoch 00058: loss improved from 0.04757 to 0.04574, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 511ms/step - loss: 0.0457 - dice_coeff: 0.9303
# Epoch 59/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0456 - dice_coeff: 0.9306
# Epoch 00059: loss improved from 0.04574 to 0.04557, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0456 - dice_coeff: 0.9306
# Epoch 60/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0446 - dice_coeff: 0.9317
# Epoch 00060: loss improved from 0.04557 to 0.04457, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0446 - dice_coeff: 0.9317
# Epoch 61/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0447 - dice_coeff: 0.9319
# Epoch 00061: loss did not improve from 0.04457
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0447 - dice_coeff: 0.9319
# Epoch 62/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0445 - dice_coeff: 0.9319
# Epoch 00062: loss improved from 0.04457 to 0.04451, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0445 - dice_coeff: 0.9319
# Epoch 63/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0444 - dice_coeff: 0.9316
# Epoch 00063: loss improved from 0.04451 to 0.04443, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0444 - dice_coeff: 0.9316
# Epoch 64/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0446 - dice_coeff: 0.9322
# Epoch 00064: loss did not improve from 0.04443
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0446 - dice_coeff: 0.9322
# Epoch 65/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0434 - dice_coeff: 0.9336
# Epoch 00065: loss improved from 0.04443 to 0.04344, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0434 - dice_coeff: 0.9336
# Epoch 66/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0425 - dice_coeff: 0.9351
# Epoch 00066: loss improved from 0.04344 to 0.04252, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0425 - dice_coeff: 0.9351
# Epoch 67/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0421 - dice_coeff: 0.9356
# Epoch 00067: loss improved from 0.04252 to 0.04210, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0421 - dice_coeff: 0.9356
# Epoch 68/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0416 - dice_coeff: 0.9367
# Epoch 00068: loss improved from 0.04210 to 0.04157, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 511ms/step - loss: 0.0416 - dice_coeff: 0.9367
# Epoch 69/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0423 - dice_coeff: 0.9351
# Epoch 00069: loss did not improve from 0.04157
# 47/47 [==============================] - 24s 504ms/step - loss: 0.0423 - dice_coeff: 0.9351
# Epoch 70/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0416 - dice_coeff: 0.9364
# Epoch 00070: loss improved from 0.04157 to 0.04156, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 512ms/step - loss: 0.0416 - dice_coeff: 0.9364
# Epoch 71/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0416 - dice_coeff: 0.9365
# Epoch 00071: loss did not improve from 0.04156
# 47/47 [==============================] - 24s 505ms/step - loss: 0.0416 - dice_coeff: 0.9365
# Epoch 72/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0402 - dice_coeff: 0.9384
# Epoch 00072: loss improved from 0.04156 to 0.04024, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 512ms/step - loss: 0.0402 - dice_coeff: 0.9384
# Epoch 73/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0412 - dice_coeff: 0.9370
# Epoch 00073: loss did not improve from 0.04024
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0412 - dice_coeff: 0.9370
# Epoch 74/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0396 - dice_coeff: 0.9391
# Epoch 00074: loss improved from 0.04024 to 0.03957, saving model to best_model.hdf5
# 47/47 [==============================] - 24s 510ms/step - loss: 0.0396 - dice_coeff: 0.9391
# Epoch 75/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0410 - dice_coeff: 0.9367
# Epoch 00075: loss did not improve from 0.03957
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0410 - dice_coeff: 0.9367
# Epoch 76/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0414 - dice_coeff: 0.9363
# Epoch 00076: loss did not improve from 0.03957
# 47/47 [==============================] - 24s 504ms/step - loss: 0.0414 - dice_coeff: 0.9363
# Epoch 77/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0632 - dice_coeff: 0.9054
# Epoch 00077: loss did not improve from 0.03957
# 47/47 [==============================] - 24s 504ms/step - loss: 0.0632 - dice_coeff: 0.9054
# Epoch 78/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0467 - dice_coeff: 0.9291
# Epoch 00078: loss did not improve from 0.03957
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0467 - dice_coeff: 0.9291
# Epoch 79/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0425 - dice_coeff: 0.9351
# Epoch 00079: loss did not improve from 0.03957
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0425 - dice_coeff: 0.9351
# Epoch 80/80
# 47/47 [==============================] - ETA: 0s - loss: 0.0412 - dice_coeff: 0.9367
# Epoch 00080: loss did not improve from 0.03957
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0412 - dice_coeff: 0.9367

# %%
model.load_weights('best_model.hdf5')

# %%
score = model.evaluate(x_valid, y_valid, batch_size=32)
print("test loss, test dice coefficient:", score)
# Out:
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0965 - dice_coeff: 0.8710
# test loss, test dice coefficient: [0.09647680819034576, 0.8710162043571472]

# %%
def compare_actual_and_predicted(image_no):
    temp = model.predict(cts[image_no].reshape(1,new_dim, new_dim, 1))

    fig = plt.figure(figsize=(15,15))

    plt.subplot(1,3,1)
    plt.imshow(cts[image_no].reshape(new_dim, new_dim), cmap='bone')
    plt.title('Original Image (CT)')

    plt.subplot(1,3,2)
    plt.imshow(infections[image_no].reshape(new_dim,new_dim), cmap='bone')
    plt.title('Actual mask')

    plt.subplot(1,3,3)
    plt.imshow(temp.reshape(new_dim,new_dim), cmap='bone')
    plt.title('Predicted mask')

    plt.show()

# %%
for i in [40,50,60,70, 355, 380, 100]:
    compare_actual_and_predicted(i)
